# %% [markdown]
# <a href="https://colab.research.google.com/github/sebastienhamel/this_is_me_teaching_again/blob/main/Quizzes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Quizzes

# %% [markdown]
# Please enter the names of the people who worked with you below

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

dataframe = pd.read_csv("/content/drive/MyDrive/data_curriculum/data_bootcamp/Week 6/student.csv")
# dataframe.info()

# # Select a column
# dataframe['name'] # returns a Series = 1 column
# print(type(dataframe['name']))

# # Select multiple columns
# dataframe[['id', 'name']] # returns a DataFrame

# # Select n first rows of a dataframe
# dataframe.head(1)

# # Select n last rows of a dataframe (n = 5 by default)
# dataframe.tail()

dataframe
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78     NaN
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row    NaN    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
dataframe['mark'].plot(kind='hist', bins=20, title='mark')
#plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# <Axes: title={'center': 'mark'}, ylabel='Frequency'>

# %%
# # Slicing
# # my_list = ["Micayla", "Mehul", "Jack", "Sara", "Tooba", "Kolyu", "Patrick"]
# # print(my_list[0:2]) # end index is exclusive
# # print(my_list[0:5:2]) # start:stop:steps
# # print(my_list[2:]) # start at index 2 until end of list
# # print(my_list[:3]) # until index 3 non included

# # dataframe.info()
# # dataframe[['id', 'name']]
# # # dataframe.loc[rows, columns]
# # dataframe.loc[:, 'id':'class']
# # dataframe.loc[:, ['id', 'name']]
# # dataframe.loc[:, 'id']

# # dataframe.loc[0:3, 'id':'name'] # df.loc is inclusive
# # dataframe.iloc[0:3, 0:2] # df.iloc is exclusive

# # dataframe.info()
# # dataframe['class']
# # # SELECT * FROM dataframe WHERE dataframe.series == Four;
# dataframe[dataframe['class'] == "Four"]

# # # SELECT * FROM dataframe WHERE dataframe.series == Four AND dataframe.series > 60
# #dataframe[(dataframe['class'] == "Four") & (dataframe['mark'] > 60)]

# # # SELECT * FROM dataframe WHERE dataframe.series == Four OR dataframe.series > 60
# dataframe[(dataframe['class'] == "Four") | (dataframe['mark'] > 60)].loc[:, 'id':'mark']
# dataframe.loc[0:2, :]

# # Get shape of dataframe
# #dataframe.shape
# Out:
# String
# Test

# %%
dataframe.loc[dataframe['class'] == 'Four']
dataframe[dataframe['class'] == 'Four'][['mark', 'gender']]
dataframe.query("`class` == \"Four\"") # filter in string using backticks ` for column names
# Out:
#     id         name class  mark  gender
# 0    1     John Deo  Four    75  female
# 3    4   Krish Star  Four    60  female
# 4    5    John Mike  Four    60  female
# 5    6    Alex John  Four    55    male
# 9   10     Big John  Four    55  female
# 15  16        Gimmy  Four    88    male
# 20  21   Babby John  Four    69  female
# 30  31  Marry Toeey  Four    88    male

# %%
# Check for nulls
dataframe.isnull()

# Number of nulls per column
dataframe.isnull().sum()

# Number of nulls in a dataframe
# dataframe.isnull() -> returns a dataframe of True and False where True
# = Empty value.sum() -> Performs a sum of all values per column
# where True = 1 and False = 0 -> Returns a Series. sum() -> Performs a sum of all rows.
dataframe.isnull().sum().sum()
# Out:
# np.int64(4)

# %%
# Name 1
# Name 2

# %% [markdown]
# Design an algorithm to add two numbers and print the result (like a really simple calculator).

# %% [markdown]
# Paste in the box the Python code which would complete this:
#
# 1. Create a variable my_name and assign it value of your Name
# 1. Print it
# 1. Check the type of data of your variable
# 1. Find the length of your name

# %% [markdown]
# Using one of the comparison operators in Python, write a simple two-line program that takes the parameter called input as input, which is an integer, and prints False if input is less than 100, and True if input is greater than or equal to 100.

# %%
something_else = 15
print(something_else)
# Out:
# 15

# %% [markdown]
# Write a script to check if a number is positive, negative or zero

# %% [markdown]
# Create a while loop that counts from 0 to 10 and prints odd numbers to the screen. Use the skeleton below:

# %%
x = 1

while x < 11:
    # Line of code.
        # Line of code.
    # Line of code.
    pass # Delete this line once you are done
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2389984844.py in <cell line: 0>()
#       1 x = 1
#       2
# ----> 3 while x < 11:
#       4     # Line of code.
#       5         # Line of code.
#
# KeyboardInterrupt:

# %% [markdown]
# Let's play a “guess the number game” using while loop.
#
# Write a program that:
# 1. Takes the number from user
# 1. Compares the number the user entered with a randomly generated number
# 1. Provide a message “Little lower” or “Little higher” till the user guesses it correctly

# %%
import random
input = 15
user_input = int(input("I have picked a number between 10 and 99, can you guess what it is? "))
number_to_guess = random.randint(10, 99)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2664985693.py in <cell line: 0>()
#       1 import random
#       2 input = 15
# ----> 3 user_input = int(input("I have picked a number between 10 and 99, can you guess what it is? "))
#       4 number_to_guess = random.randint(10, 99)
#       5
#
# TypeError: 'int' object is not callable

# %% [markdown]
# Write a Python program to print numbers from 1 to 50, you must use the range() function.

# %% [markdown]
# Write a code to print all even numbers from 0 to 100.

# %% [markdown]
# ### To share your file
#
# 1. Take screenshots of every task
# 1. Paste them at the end of your workbook

# %%
import pandas as pd

data = {
    "calories": [420, 380, 390],
    "duration": [50, 40, None]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

#print(df)
df.info()
print(type(df))
print(type("Stella"))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   calories  3 non-null      int64
#  1   duration  3 non-null      int64
# dtypes: int64(2)
# memory usage: 180.0 bytes
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
